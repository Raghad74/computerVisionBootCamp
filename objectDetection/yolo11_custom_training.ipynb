# %%
import ultralytics

# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\ragha\\OneDrive\\Desktop\\CV COURSE\\objectDetection'

# %% [markdown]
# ## using the command line interface

# %% [markdown]
# the number of epochs is low because I am running it on cpu not gpu

# %%
# !yolo train model=yolo11m.pt data='dataset\data.yaml' epochs=3 imgsz=640
# Out:
# ^C
# New https://pypi.org/project/ultralytics/8.3.213 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.207  Python-3.13.5 torch-2.8.0+cu129 CPU (11th Gen Intel Core i7-1165G7 @ 2.80GHz)
# ...
