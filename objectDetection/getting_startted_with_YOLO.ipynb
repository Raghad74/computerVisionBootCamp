# %%
import ultralytics
import cv2
import matplotlib.pyplot as plt

# %%
def imsh(image_path):
    image=cv2.imread(image_path)
    if image is None:
        print("error: image not found")
        return
    plt.imshow(cv2.cvtColor(image,cv2.COLOR_BGR2RGB))

# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\ragha\\OneDrive\\Desktop\\CV COURSE\\objectDetection'

# %%
# !yolo predict model=yolo11n.pt source='images/girrafs.jpg'
# Out:
# Ultralytics 8.3.207  Python-3.13.5 torch-2.8.0+cu129 CPU (11th Gen Intel Core i7-1165G7 @ 2.80GHz)
# YOLO11n summary (fused): 100 layers, 2,616,248 parameters, 0 gradients, 6.5 GFLOPs
#
# image 1/1 c:\Users\ragha\OneDrive\Desktop\CV COURSE\objectDetection\images\girrafs.jpg: 448x640 1 elephant, 3 giraffes, 315.8ms
# Speed: 6.7ms preprocess, 315.8ms inference, 8.4ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to C:\Users\ragha\OneDrive\Desktop\CV COURSE\objectDetection\runs\detect\predict2
#  Learn more at https://docs.ultralytics.com/modes/predict

# %%
imsh('runs/detect/predict2/girrafs.jpg')

# %%
# !yolo predict model=yolo11s.pt source='images/girrafs.jpg'
# Out:
# ...
# Ultralytics 8.3.207  Python-3.13.5 torch-2.8.0+cu129 CPU (11th Gen Intel Core i7-1165G7 @ 2.80GHz)
# YOLO11s summary (fused): 100 layers, 9,443,760 parameters, 0 gradients, 21.5 GFLOPs
#
# image 1/1 c:\Users\ragha\OneDrive\Desktop\CV COURSE\objectDetection\images\girrafs.jpg: 448x640 1 elephant, 3 giraffes, 179.9ms
# Speed: 3.2ms preprocess, 179.9ms inference, 2.5ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to C:\Users\ragha\OneDrive\Desktop\CV COURSE\objectDetection\runs\detect\predict3
#  Learn more at https://docs.ultralytics.com/modes/predict

# %%
imsh('runs/detect/predict3/girrafs.jpg')

# %%
# !yolo predict model=yolo11m.pt source='images/girrafs.jpg'
# Out:
# ...
# Ultralytics 8.3.207  Python-3.13.5 torch-2.8.0+cu129 CPU (11th Gen Intel Core i7-1165G7 @ 2.80GHz)
# YOLO11m summary (fused): 125 layers, 20,091,712 parameters, 0 gradients, 68.0 GFLOPs
#
# image 1/1 c:\Users\ragha\OneDrive\Desktop\CV COURSE\objectDetection\images\girrafs.jpg: 448x640 1 elephant, 3 giraffes, 435.3ms
# Speed: 3.5ms preprocess, 435.3ms inference, 2.9ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to C:\Users\ragha\OneDrive\Desktop\CV COURSE\objectDetection\runs\detect\predict4
#  Learn more at https://docs.ultralytics.com/modes/predict

# %%
imsh('runs/detect/predict4/girrafs.jpg')

# %%
# !yolo predict model=yolo11l.pt source='images/girrafs.jpg'
# Out:
# ...
# Ultralytics 8.3.207  Python-3.13.5 torch-2.8.0+cu129 CPU (11th Gen Intel Core i7-1165G7 @ 2.80GHz)
# YOLO11l summary (fused): 190 layers, 25,340,992 parameters, 0 gradients, 86.9 GFLOPs
#
# image 1/1 c:\Users\ragha\OneDrive\Desktop\CV COURSE\objectDetection\images\girrafs.jpg: 448x640 3 giraffes, 839.5ms
# Speed: 3.9ms preprocess, 839.5ms inference, 2.6ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to C:\Users\ragha\OneDrive\Desktop\CV COURSE\objectDetection\runs\detect\predict5
#  Learn more at https://docs.ultralytics.com/modes/predict

# %%
imsh('runs/detect/predict5/girrafs.jpg')

# %%
# !yolo predict model=yolo11x.pt source='images/girrafs.jpg'
# Out:
# ...
# Ultralytics 8.3.207  Python-3.13.5 torch-2.8.0+cu129 CPU (11th Gen Intel Core i7-1165G7 @ 2.80GHz)
# YOLO11x summary (fused): 190 layers, 56,919,424 parameters, 0 gradients, 194.9 GFLOPs
#
# image 1/1 c:\Users\ragha\OneDrive\Desktop\CV COURSE\objectDetection\images\girrafs.jpg: 448x640 3 giraffes, 1567.1ms
# Speed: 2.7ms preprocess, 1567.1ms inference, 2.7ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to C:\Users\ragha\OneDrive\Desktop\CV COURSE\objectDetection\runs\detect\predict6
#  Learn more at https://docs.ultralytics.com/modes/predict

# %%
imsh('runs/detect/predict6/girrafs.jpg')
